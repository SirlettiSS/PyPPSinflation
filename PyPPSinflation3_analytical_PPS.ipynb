# %% [markdown]
# ## **PyPPSinflation notebook 3: Analytical PPS**

# %% [markdown]
# This can be considered the third notebook of PyPSSinflation.

# %% [markdown]
# ## **Analytical solutions of the primordial power spectra (PPS) up to the third order.**

# %% [markdown]
# In this notebook we want to compute the analytical PPS at first-, second- and third-order. Doing it we will be able to compare the analytical PPS with respect to the numerical PPS computed in the numerical notebook.

# %% [markdown]
# The PPS, both scalar and tensor, are parametrized in the slow-roll regime for every model $V(\phi)$ up to the third order as
#
# $ \frac{\mathcal{P}(k)}{\mathcal{P}_0(k_*)} = a_0 + a_1 \ln\left(\frac{k}{k_*}\right) + \frac{a_2}{2}\ln^2\left(\frac{k}{k_*}\right) +\frac{a_3}{6} \ln^3\left(\frac{k}{k_*}\right),$
#
# with
#
# $ \mathcal{P}_{\mathcal{R}_0}(k_*) = \frac{H^2}{8\pi^2 \varepsilon_1 M^2_{Pl}} \ \ \ and \ \ \ \mathcal{P}_{\mathcal{h}_0}(k_*) = \frac{2 H^2}{\pi^2 M^2_{Pl}},$
#
# where $H$ and $\varepsilon_1$ are evaluated at $k_*=aH$.
#
# It is possibile to find the expressions of the $a_{Si}$ and the $a_{Ti}$ in the corrisponding paper of PyPPSinflation: **Ballardini, M. and Davoli, A. and Sirletti, S. S. - Third-order corrections to the slow-roll expansion: calculation and constraints with Planck, ACT, and SPT**.
#
# $ a_{S0} =   1 - 2 (1 + C) \varepsilon_{1*} + \left( -3 + 2 C + 2 C^2 + \frac{\pi^2}{2} \right) \varepsilon_{1*}^2 - C \varepsilon_{2*} + \left( -6 - C + C^2 + \frac{7 \pi^2}{12} \right) \varepsilon_{1*} \varepsilon_{2*} + \frac{1}{8} \left( -8 + 4 C^2 + \pi^2 \right) \varepsilon_{2*}^2+ \frac{1}{24} \left( -12 C^2 + \pi^2 \right) \varepsilon_{2*} \varepsilon_{3*} - \frac{1}{24} \left( -16 - 24 C + 4 C^3 + 3 C \pi^2 + 2 \zeta(3) \right) (8 \varepsilon_{1*}^3 + \varepsilon_{2*}^3)+ \frac{1}{12} \left( 72 C + 36 C^2 + 13 \pi^2 - 8 C \pi^2 - 12 \zeta(3) \right) \varepsilon_{1*}^2 \varepsilon_{2*}- \frac{1}{24} \left( 16 - 24 C - 12 C^2 + 8 C^3 - 15 \pi^2 + 6 C \pi^2 + 28 \zeta(3) \right) \varepsilon_{1*} \varepsilon_{2*}^2+ \frac{1}{24} \left( 16 - 4 C^3 + C \pi^2 - 8 \zeta(3) \right) ( \varepsilon_{2*} \varepsilon_{3*}^2 + \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*})+ \frac{1}{24} \left( -48 C + 12 C^3 + 5 C \pi^2 \right) \varepsilon_{2*}^2 \varepsilon_{3*}+ \frac{1}{12} \left( -8 - 72 C - 12 C^2 + 8 C^3 + \pi^2 + 6 C \pi^2 - 8 \zeta(3) \right) \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*}$
#
#
# $a_{S1} =  -2 \varepsilon_{1*} + 2 (2 C + 1) \varepsilon_{1*}^2 - \varepsilon_{2*} + (2 C - 1) \varepsilon_{1*} \varepsilon_{2*} + C \varepsilon_{2*}^2 - C \varepsilon_{2*} \varepsilon_{3*}- \frac{1}{8} \left( -8 + 4 C^2 + \pi^2 \right) (8 \varepsilon_{1*}^3 + \varepsilon_{2*}^3) - \frac{2}{3} \left( -9 - 9 C + \pi^2 \right) \varepsilon_{1*}^2 \varepsilon_{2*}- \frac{1}{4} \left( -4 - 4 C + 4 C^2 + \pi^2 \right) \varepsilon_{1*} \varepsilon_{2*}^2 + \frac{1}{2} \left( -12 - 4 C + 4 C^2 + \pi^2 \right) \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*}+ \frac{1}{24} \left( -12 C^2 + \pi^2 \right) ( \varepsilon_{2*} \varepsilon_{3*}^2 + \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*})+ \frac{1}{24} \left( -48 + 36 C^2 + 5 \pi^2 \right) \varepsilon_{2*}^2 \varepsilon_{3*}$
#
# $a_{S2} =  4 \varepsilon_{1*}^2 + 2 \varepsilon_{1*} \varepsilon_{2*} + 6 \varepsilon_{1*}^2 \varepsilon_{2*} + \varepsilon_{2*}^2 - \varepsilon_{2*} \varepsilon_{3*}  + (1 - 2C) (\varepsilon_{1*} \varepsilon_{2*}^2 - 2 \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*}) - C (8 \varepsilon_{1*}^3 + \varepsilon_{2*}^3 - 3 \varepsilon_{2*}^2 \varepsilon_{3*} + \varepsilon_{2*} \varepsilon_{3*}^2 + \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*})$
#
# $a_{S3} = -8 \varepsilon_{1*}^3 - 2 \varepsilon_{1*} \varepsilon_{2*}^2 - \varepsilon_{2*}^3 + 4 \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*}  + 3 \varepsilon_{2*}^2 \varepsilon_{3*} - \varepsilon_{2*} \varepsilon_{3*}^2 - \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*}$
#
# $a_{T0} =  1 + (-2 - 2 C) \varepsilon_{1*} + \frac{1}{2} (-6 + 4 C + 4 C^2 + \pi^2) \varepsilon_{1*}^2    + \frac{1}{12} (-24 - 24 C - 12 C^2 + \pi^2) \varepsilon_{1*} \varepsilon_{2*} - \frac{1}{3} (-16 - 24 C + 4 C^3 + 3 C \pi^2 + 2 \zeta(3)) \varepsilon_{1*}^3   + \frac{1}{12} (-96 - 72 C + 36 C^2 + 24 C^3 + 13 \pi^2 + 10 C \pi^2) \varepsilon_{1*}^2 \varepsilon_{2*}     - \frac{1}{12} (8 + 24 C + 12 C^2 + 4 C^3 - \pi^2 - C \pi^2 + 8 \zeta(3)) (\varepsilon_{1*} \varepsilon_{2*}^2 + \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*})$
#
# $a_{T1} = -2 \varepsilon_{1*} + 2 \varepsilon_{1*}^2 +    4 C \varepsilon_{1*}^2 + (-2 - 2 C) \varepsilon_{1*} \varepsilon_{2*} - (-8 + 4 C^2 + \pi^2) \varepsilon_{1*}^3+ \frac{1}{6} (-36 + 36 C + 36 C^2 + 5 \pi^2) \varepsilon_{1*}^2 \varepsilon_{2*} +   \frac{1}{12} (-24 - 24 C - 12 C^2 + \pi^2) (\varepsilon_{1*} \varepsilon_{2*}^2 + \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*})$
#
#
# $ a_{T2} =   4 \varepsilon_{1*}^2 - 8 C \varepsilon_{1*}^3 -2   \varepsilon_{1*} \varepsilon_{2*} + 2(3 + 6 C) \varepsilon_{1*}^2 \varepsilon_{2*} - 2(C + 1) (\varepsilon_{1*} \varepsilon_{2*}^2 + 2\varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*})$
#
#
# $ a_{T3} = -8 \varepsilon_{1*}^3 + 12 \varepsilon_{1*}^2 \varepsilon_{2*} -2 \varepsilon_{1*} \varepsilon_{2*}^2 - 2\varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*}$
#
#
# where $C\simeq -0.7296$ and the subscript $*$ means that the quantity is computed at $k_*$ or at $N_*$ equivalentely.
#
#
# It is also possibile to write the logarithmic version of the spectra, using the $b_{Si}$ and $b_{Ti}$ coefficients:
#
# $\ln\left(\frac{P(k)}{P_0(k_*)} \right) = b_0 + b_1 \ln\left(\frac{k}{k_*}\right)+ \frac{b_2}{2}\ln^2\left(\frac{k}{k_*}\right)+\frac{b_3}{6} \ln^3\left(\frac{k}{k_*}\right) $
#
# where
#
# $ b_{S0} =   -2 (1 + C) \varepsilon_{1*} + \left(-5 - 2 C + \frac{\pi^2}{2}\right) \varepsilon_{1*}^2 - C \varepsilon_{2*} + \left(-6 - 3 C - C^2 + \frac{7 \pi^2}{12}\right) \varepsilon_{1*} \varepsilon_{2*} + \frac{1}{24} \left(-12 C^2 + \pi^2\right) \varepsilon_{2*} \varepsilon_{3*} - \frac{1}{24} \left(80 + 48 C - 24 \pi^2 + 16 \zeta(3)\right) \varepsilon_{1*}^3 + \frac{1}{8} \left(-8 + \pi^2\right) \varepsilon_{2*}^2  \notag \\ - \frac{1}{24} \left(-16 + 2 \zeta(3)\right) \varepsilon_{2*}^3 + \frac{1}{12} \left(-144 - 180 C - 36 C^2 + 27 \pi^2 + 12 C \pi^2 - 12 \zeta(3)\right) \varepsilon_{1*}^2 \varepsilon_{2*} - \frac{1}{24} \left(64 + 168 C + 36 C^2 + 8 C^3 - 21 \pi^2 - 14 C \pi^2 + 28 \zeta(3)\right) \varepsilon_{1*} \varepsilon_{2*}^2 + \frac{1}{24} \left(16 - 4 C^3 + C \pi^2 - 8 \zeta(3)\right) (\varepsilon_{2*} \varepsilon_{3*}^2 + \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*})  + \frac{1}{24} \left(-48 C + 6 C \pi^2\right) \varepsilon_{2*}^2 \varepsilon_{3*} + \frac{1}{12} \left(-8 - 72 C - 24 C^2 - 4 C^3 + 2 \pi^2 + 7 C \pi^2 - 8 \zeta(3)\right) \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*} $
#
# $b_{S1} =  -2 \varepsilon_{1*} - 2 \varepsilon_{1*}^2 - 2 \varepsilon_{1*}^3 - \varepsilon_{2*} - (3 + 2 C) \varepsilon_{1*} \varepsilon_{2*} - C \varepsilon_{2*} \varepsilon_{3*} - \frac{2}{3} \left( \frac{45}{2} + 9 C - \frac{3 \pi^2}{2} \right) \varepsilon_{1*}^2 \varepsilon_{2*}  - \frac{1}{4} \left( 28 + 12 C + 4 C^2 - \frac{7 \pi^2}{3} \right) \varepsilon_{1*} \varepsilon_{2*}^2 + \frac{1}{2} \left( -12 - 8 C - 2 C^2 + \frac{7 \pi^2}{6} \right) \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*} + \frac{1}{24} \left( -12 C^2 + \pi^2 \right) \left( \varepsilon_{2*} \varepsilon_{3*}^2 + \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*} \right) + \frac{1}{24} \left( -48 + 6 \pi^2 \right) \varepsilon_{2*}^2 \varepsilon_{3*}  $
#
# $ b_{S2} = -2 \varepsilon_{1*} \varepsilon_{2*} - 6 \varepsilon_{1*}^2 \varepsilon_{2*} - (3 + 2 C) \varepsilon_{1*} \varepsilon_{2*}^2 - \varepsilon_{2*} \varepsilon_{3*}- 2 (2 + C) \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*} - C \varepsilon_{2*} \varepsilon_{3*}^2 - C \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*} $
#
# $ b_{S3} =- 2 \varepsilon_{1*} \varepsilon_{2*}^2 - 2 \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*} - \varepsilon_{2*} \varepsilon_{3*}^2 - \varepsilon_{2*} \varepsilon_{3*} \varepsilon_{4*} $
#
# $b_{T0} =  -2 (1 + C) \varepsilon_{1*} + \frac{1}{2} (-10 - 4 C + \pi^2) \varepsilon_{1*}^2  + \frac{1}{12} (-24 - 24 C - 12 C^2 + \pi^2) \varepsilon_{1*} \varepsilon_{2*}  - \frac{1}{3} (10 + 6 C - 3 \pi^2 + 2 \zeta(3)) \varepsilon_{1*}^3  + \frac{1}{12} (-144 - 168 C - 36 C^2 + 15 \pi^2 + 12 C \pi^2) \varepsilon_{1*}^2 \varepsilon_{2*}  - \frac{1}{12} (8 + 24 C + 12 C^2 + 4 C^3 - \pi^2 - C \pi^2 + 8 \zeta(3)) (\varepsilon_{1*} \varepsilon_{2*}^2 + \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*})$
#
# $b_{T1} =  -2 \varepsilon_{1*} - 2 \varepsilon_{1*}^2 + (-2 - 2 C) \varepsilon_{1*} \varepsilon_{2*} - 2 \varepsilon_{1*}^3  + \frac{1}{6} (-84 - 36 C + 6 \pi^2) \varepsilon_{1*}^2 \varepsilon_{2*}  + \frac{1}{12} (-24 - 24 C - 12 C^2 + \pi^2) (\varepsilon_{1*} \varepsilon_{2*}^2 + \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*})$
#
# $ b_{T2} =  -2 \varepsilon_{1*} \varepsilon_{2*} - 6 \varepsilon_{1*}^2 \varepsilon_{2*} - 2 (1 + C) \varepsilon_{1*} \varepsilon_{2*}^2 - 2 (1 + C) \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*} $
#
# $b_{T3} =   -2 \varepsilon_{1*} \varepsilon_{2*}^2 - 2 \varepsilon_{1*} \varepsilon_{2*} \varepsilon_{3*}$
#
#
# We also chose to consider the case of third-order PPS with $\epsilon_4=0$. This case can be particularly insightful when examining constraints on $\epsilon_4$.
#
# The solution found here is slightly different from the one presente by Auclair and Ringeval in Slow-Roll Inflation at N3LO (arXiv:2205.12608) because for the triple integral (they call it $F_{000}$) in the $y_{31A}$ solution they found a term $-\frac{7}{3}\zeta(3)$, while we found $-\frac{1}{3}\zeta(3)$. This difference changes some of the $\zeta(3)$ terms in $a_{S/T0}$ and $b_{S/T0}$, without changing the oter quantities.
#
#
# From our solution to the Auclair and Ringeval one we have the following differences:
#
# - For $b_{0S}$: $16\zeta(3) \varepsilon_1^3  \ \ \longrightarrow \ \ 112 \zeta(3) \varepsilon_1^3 $, $2\zeta(3)  \varepsilon_2^3) \ \ \longrightarrow \ \ 14 \zeta(3) \varepsilon_2^3$, $-12\zeta(3) \varepsilon_1^2 \varepsilon_2 \ \ \longrightarrow \ \ -84\zeta(3) \varepsilon_1^2 \varepsilon_2$, and $28\zeta(3) \varepsilon_1 \varepsilon_2^2 \ \ \longrightarrow \ \ -100\zeta(3) \varepsilon_1 \varepsilon_2^2$.
#
# - For $a_{0S}$: $2\zeta(3) (8\varepsilon_1^3 + \varepsilon_2^3) \ \ \longrightarrow \ \ 14 \zeta(3) (8\varepsilon_1^3 + \varepsilon_2^3)$, $-12\zeta(3) \varepsilon_1^2 \varepsilon_2 \ \ \longrightarrow \ \ -84\zeta(3) \varepsilon_1^2 \varepsilon_2$, and $28\zeta(3) \varepsilon_1 \varepsilon_2^2 \ \ \longrightarrow \ \ -100\zeta(3) \varepsilon_1 \varepsilon_2^2$.
#
# - For $b_{0T}$ and $a_{0S}$: $2\zeta(3) \varepsilon_1^3  \ \ \longrightarrow \ \ 14 \zeta(3) \varepsilon_1^3$.
#
# At the end of this notebook, we compute the differences between the two results.
#
#
#
# -----
#
# By approximating at leading order (LO) $H^2$ as
#
# $H^2 \simeq \frac{1}{3M^2_{Pl}} V,$
#
# it is possible to find
#
# $\frac{d}{dN}\Bigg|^{LO} = -M^2_{\text{Pl}} \frac{V_\phi}{V}\frac{d}{d\phi},$
#
#
# and from it the $\varepsilon_i$ at leading order are found to be analytically:
#
#
# $\varepsilon_1^{LO} \simeq \frac{M^2_{Pl}}{2} \left(\frac{V'}{V}\right)^2,$
#
# $\varepsilon_2^{LO} \simeq 2M^2_{Pl}\left[\left(\frac{V'}{V}\right)^2-\frac{V''}{V}\right],$
#
# $\varepsilon_2^{LO} \varepsilon_3^{LO} \simeq 2M^4_{Pl}\left[\frac{V''' V'}{V^2}-\frac{3V'' V'^2}{V^3} +2\left(\frac{V'}{V}\right)^4\right],$
#
# $\epsilon_4^{LO} = \frac{2 M_{\text{Pl}}^6}{\epsilon_2 \epsilon_3} \bigg[\frac{8 V_\phi^6}{V^6} - \frac{17 V_\phi^4 V_{\phi\phi}}{V^5} + \frac{6 V_\phi^2 V_{\phi\phi}^2}{V^4} + \frac{5 V_\phi^3 V_{\phi\phi\phi}}{V^4} - \frac{V_\phi V_{\phi\phi} V_{\phi\phi\phi}}{V^3} - \frac{V_\phi^2 V_{\phi\phi\phi\phi}}{V^3}  + \frac{2 M_{\text{Pl}}^2}{\epsilon_2} \bigg( - \frac{4 V_\phi^8}{V^8} + \frac{12 V_\phi^6 V_{\phi\phi}}{V^7} - \frac{9 V_\phi^4 V_{\phi\phi}^2}{V^6} - \frac{4 V_\phi^5 V_{\phi\phi\phi}}{V^6} + \frac{6 V_\phi^3 V_{\phi\phi} V_{\phi\phi\phi}}{V^5}  - \frac{V_\phi^2 V_{\phi\phi\phi}^2}{V^4} \bigg) \bigg].$
#
#
# These equations can be developed at higher order by searching for the equations at next to the leading order (NLO). Starting from the Friedmann equation and the **exact** equations
#
# $H^2 = \frac{V}{3M_{\text{Pl}}} \left(1-\frac{\varepsilon_1}{3}\right)^{-1} \ \ \ \text{and} \ \ \ dN = \pm \frac{1}{M_{\text{Pl}}} \frac{d\phi}{\sqrt{2\varepsilon_1}},$
#
# it is possibile to find
#
# $\varepsilon_0 = \varepsilon_0^{LO} \sqrt{1-\frac{\varepsilon_1}{3}}$
#
# and
#
# $\frac{d}{dN}\Bigg|^{NLO} = \sqrt{\frac{\varepsilon_1^{NLO}}{\varepsilon_1^{LO}}} \frac{d}{dN}\Bigg|^{LO}.$
#
# Using the latter equations it is possible to find the the $\varepsilon_i$ at higher orders. If we expand up to a certain order, it is possible to reach up to the next-next-next-leading-order (N3LO):
#
# $\varepsilon_1^{N3LO} = \varepsilon_1^{LO} - \frac{1}{3} \varepsilon_1^{LO} \varepsilon_2^{LO} - \frac{1}{9} \varepsilon_1^{LO^{2}} \varepsilon_2^{LO} + \frac{5}{36} \varepsilon_1^{LO} \varepsilon_2^{LO^{2}} + \frac{1}{9} \varepsilon_1^{LO} \varepsilon_2^{LO} \varepsilon_3^{LO}$
#
# $\varepsilon_2^{N3LO} = \varepsilon_2^{LO} - \frac{1}{6} \varepsilon_2^{LO^{2}} - \frac{1}{3} \varepsilon_2^{LO} \varepsilon_3^{LO} - \frac{1}{6} \varepsilon_1^{LO} \varepsilon_2^{LO^{2}} + \frac{1}{18} \varepsilon_2^{LO^{3}} - \frac{1}{9} \varepsilon_1^{LO} \varepsilon_2^{LO} \varepsilon_3^{LO} + \frac{5}{18} \varepsilon_2^{LO^{2}} \varepsilon_3^{LO} + \frac{1}{9} \varepsilon_2^{LO} \varepsilon_3^{LO^{2}} + \frac{1}{9} \varepsilon_2^{LO} \varepsilon_3^{LO} \varepsilon_4^{LO}$
#
# $\varepsilon_3^{N3LO} = \varepsilon_3^{LO} - \frac{1}{3} \varepsilon_2^{LO} \varepsilon_3^{LO} - \frac{1}{3} \varepsilon_3^{LO} \varepsilon_4^{LO} - \frac{1}{6} \varepsilon_1^{LO} \varepsilon_2^{LO^{2}} - \frac{1}{3} \varepsilon_1^{LO} \varepsilon_2^{LO} \varepsilon_3^{LO} + \frac{1}{6} \varepsilon_2^{LO^{2}} \varepsilon_3^{LO} + \frac{5}{18} \varepsilon_2^{LO} \varepsilon_3^{LO^{2}} - \frac{1}{9} \varepsilon_1^{LO} \varepsilon_3^{LO} \varepsilon_4^{LO} + \frac{5}{18} \varepsilon_2^{LO} \varepsilon_3^{LO} \varepsilon_4^{LO} + \frac{1}{9} \varepsilon_3^{LO^{2}} \varepsilon_4^{LO} + \frac{1}{9} \varepsilon_3^{LO} \varepsilon_4^{LO^{2}} + \frac{1}{9} \varepsilon_3^{LO} \varepsilon_4^{LO} \varepsilon_5^{LO}
# $
#
# $\varepsilon_4^{N3LO} = \varepsilon_4^{LO} - \frac{1}{3} \varepsilon_2^{LO} \varepsilon_3^{LO} - \frac{1}{6} \varepsilon_2^{LO} \varepsilon_4^{LO} - \frac{1}{3} \varepsilon_4^{LO} \varepsilon_5^{LO}$
#
#
# For more details, see V. Vennin - Horizon-Flow off-track for Inflation (https://arxiv.org/abs/1401.2926) and J. Martin et. al. - Cosmic Inflation at the Crossroads (https://arxiv.org/abs/2404.10647).
#
# The analytical PPS are compute both at LO and N3LO, where we take the N3LO spectra as PPS to be compared with the numerical results.
#
#
# -----
#
# For the background and its relation with the e-folds number, we have:
#
# $N_{end}- N \simeq -\frac{1}{M^2_{Pl}} \int_{\phi}^{\phi_{end}} \frac{V}{V'} d\phi$,
#
# where we define $\phi_{end}$ to be the value when $\varepsilon_1=1$.
#
# -----
#
# We want to follow these steps:
#
# 1. Define the potential, i.e., define the model.
#
# 2. Compute $V$, $V'$, $V''$, $\varepsilon_1$, $\varepsilon_2$, $\varepsilon_3$, and $\varepsilon_4$.
#
# 3. Compute $\phi_{end}$ from $\varepsilon_1(\phi_{end})=1$.
#
# 4. Compute $\Delta N$.
#
# 5. Invert the result from the previous step to find $\phi(\Delta N)$.
#
# 6. Rewrite the expressions in terms of $\Delta N$.
#
# 7. Compute $a_{S0,1,2}$ and $a_{T0,1,2}$.
#
# 8. Compute $\mathcal{P}(k)$.
#
# Note that at first order, terms like $\varepsilon^2_1, \varepsilon^2_2, \varepsilon_2\varepsilon_3$, etc., are set to zero, simplifying the equations for $a_{S/T}$. At second order, the equations are complete. In Vennin's paper, the approach differs as he modifies the equations for $H$ and $\varepsilon_i$.
#
# Steps 1 to 6 should be computed analytically by hand, or at most by using analytical software such as Mathematica or Maple. The PyPPSinflation package includes a Wolfram Mathematica notebook, Quantities_wrt_N, which can compute steps 1 to 6 analytically for any inflation model. Steps 7 and 8 are computed in this Jupyter notebook.
#
#
# ----
#
# Using the expressions for the logarithmic PSS it is really easy to find:
#
# $n_S = 1+ b_{1S} + b_{2S} \ln\left(\frac{k}{k_*}\right) + \frac{b_{3S}}{2}\ln^2\left(\frac{k}{k_*}\right)$
#
# $ \alpha_S = b_{2S} + b_{3S}\ln\left(\frac{k}{k_*}\right)$
#
# $\beta_{S} = b_{3S}$
#
# $n_T = b_{1T} + b_{2T} \ln\left(\frac{k}{k_*}\right) + \frac{b_{3T}}{2}\ln^2\left(\frac{k}{k_*}\right)$
#
# $\alpha_T = b_{2T} + b_{3T}\ln\left(\frac{k}{k_*}\right)$
#
# $ \beta_{T} = b_{3T}$.

# %% [markdown]
# ## An example of analytical computation with the simplest model: $\frac{1}{2}m^2 \phi^2$.

# %% [markdown]
# In this notebook, we use the KKLT model as an example. Since its equations are too lengthy, we also present the simplest model of inflation for computation examples.
#
# For the $V(\phi) = \frac{1}{2}m^2\phi^2$ model, performing all the calculations (which are simple enough to be done by hand) yields:

# %% [markdown]
# $H^2 = \frac{m^2 \phi^2}{6 M^2_{Pl}}$
#
# $\varepsilon_1 =\frac{ 2M^2_{Pl}}{\phi^2}$
#
# $\varepsilon_2 =\varepsilon_3= 2\varepsilon_1$
#
# From the equation $\varepsilon_1(\phi_{end}) =1$ we get $\phi^2_{end} = 2 M^2_{Pl}$, and integrating the $\Delta N$ and inverting it we get
#
# $\phi^2 = 4 M^2_{Pl} \left(\Delta N + \frac{1}{2} \right).$
#
# Substituting we have
#
# $\varepsilon_1  = \frac{\varepsilon_2}{2}= \frac{\varepsilon_3}{2}=\frac{1}{2\Delta N +1} \ \ \ and \ \ \ H^2 = \frac{2}{3} m^2(\Delta N+\frac{1}{2})$,
#
# and then we are able to easely compute the PPS.

# %% [markdown]
# ## The choice of the coupling constant

# %% [markdown]
# In the first notebook of PyPPSinflation, which is dedicated to numerical computation, we explain the procedure for normalization, specifically the choice of the coupling constant. Here, we focus on the second step of that procedure, which concerns normalization for the analytical part.
#
# Let's recall some important points:
#
# We choose the coupling constant of the theory, which in this case is the mass, by imposing that the scalar primordial power spectrum at the pivot scale has the value $\mathscr{P}_{R}(k_*) = a_0 \mathscr{P}_{0R}(k_*) = 2\times 10^{-9}$.
#
# To achieve the same value of the PPS at the pivot scale for both numerical and analytical computations, it is possible to use different coupling constants.
#
# At the end of this notebook, we will address the normalization of the analytical coupling constant(s).

# %% [markdown]
# # Alert:
#
# In case the model returns equations that are too difficult to handle, it is possible to simplify the process by computing the analytical PPS using $H(N_*)$ and all the $\epsilon_i(N_*)$ values obtained from the numerical PPS. While this approach is not a fully rigorous method for computing the analytical PPS, it has been used in similar cases, such as in Leach et al. (\href{https://arxiv.org/abs/astro-ph/0202094}{arXiv:astro-ph/0202094}).
#
# In this case you need to redefine the functions eps1(N), eps2(N),...,H_sq1(mass,N),..., and H_sq3(mass,N) as the costant value found in the numerical script.
#
# At the end of the notebook, during the renormalization, remember to take the value of $H$ divided by the mass.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.special import zeta, polygamma, factorial

# %%
from scipy.integrate import solve_ivp
from scipy.integrate import odeint #This is a scipy package to solve ode.
from scipy.interpolate import interp1d, interp2d #We want to make an interpolation in order to have not a set of arrays but punctual functions.
from scipy import optimize #this is needed to find the roots of phi (in the case we want to use a script, but better to make it by hand)

# %%
#Defining model and its parameters.

#MODEL :  M^4 (1+mu/\phi)^-1 (We use the KKLT model as example)

Mpl=1
mu=1

#Masses for LO spectra
m2an_s_LO= 1.7399076640210377e-05
m2an_s_noeps4_LO = 1.739907869677529e-05 #coupling constant when considering eps4=0
m2an_t_LO= 1.7399076640210377e-05

#Masses for N3LO spectra
m2an_s= 1.733192366526448e-05
m2an_s_noeps4 = 1.7331925642516728e-05 #coupling constant when considering eps4=0
m2an_t= 1.733192366526448e-05

# %%
# After the analytical computations (see the 2nd notebook), we have the following epsilon_i for KKLT:


def eps1_LO(N):      
    eps1_LO = 8 * ( mu )**( 2 ) * ( ( ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + 
-1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * 
mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 1/3 
) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * 
mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 
1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 
12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 
2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( -1/3 ) ) 
) )**( -4 ) * ( ( 1 + 2 * mu * ( ( ( ( 12 * N * mu + ( ( ( 2 
)**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 
1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + 
-3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * 
mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) 
) )**( 1/3 ) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * 
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) 
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) 
)**( -1/3 ) ) ) )**( -1 ) ) )**( -2 )
    return eps1_LO

def eps2_LO(N):
    eps2_LO = 32 * mu * ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * 
( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( 
mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * 
( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 
1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) * ( ( mu )**( 2 ) + ( ( 12 
* N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 
2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 
( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * N + 
( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) 
)**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) * ( ( ( mu )**( 2 ) + ( -1 
* mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( 
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu 
)**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 
6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 1/3 ) + ( ( 12 * N * 
mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 
)**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 
1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) 
)**( 1/2 ) ) ) )**( 2/3 ) ) ) )**( -2 ) * ( ( ( mu )**( 2 ) + ( mu * 
( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 
2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 
) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * 
N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 1/3 ) + ( ( 12 * N * mu 
+ ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 
1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 
) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) 
)**( 1/2 ) ) ) )**( 2/3 ) ) ) )**( -2 )
    return eps2_LO

def eps3_LO(N):
    eps3_LO= -8 * mu * ( -12 * N * mu + ( -1 * ( 2 )**( 1/2 ) * mu * ( mu * ( 
2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( ( mu )**( 2 ) * ( mu * ( 2 * 
( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + -1 * ( 2 )**( 1/2 ) * ( ( mu )**( 
2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * 
mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 
)**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) * ( ( ( mu )**( 2 ) 
+ ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * 
( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 
2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * 
N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) )**( -1 ) * ( ( ( mu 
)**( 2 ) + ( -1 * mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 
* mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * 
mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 1/3 
) + ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu 
)**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 
6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) ) )**( -2 ) * ( ( 
( mu )**( 2 ) + ( mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 
* mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * 
mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 1/3 
) + ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu 
)**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 
6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) ) )**( -2 ) * ( 3 
* ( mu )**( 4 ) + ( 3 * mu * ( 12 * N + ( 2 )**( 1/2 ) * ( mu * 
( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) * ( ( 12 * N * mu + ( ( 
2 )**( 1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 
-1 * ( mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + 
( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * 
( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 
* mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) 
) ) ) )**( 1/3 ) + ( 3 * ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( 
N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) * ( ( 12 * N * mu + ( ( 2 )**( 
1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( -1 * ( 
mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 
)**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * 
mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) 
) ) )**( 1/3 ) + -1 * ( mu )**( 2 ) * ( 3 * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) * ( ( 12 * N * mu + ( ( 2 )**( 1/2 ) * mu * 
( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( -1 * ( mu )**( 2 ) 
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( 
( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + 
-3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * 
( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) )**( 1/3 
) + -7 * ( ( 12 * N * mu + ( ( 2 )**( 1/2 ) * mu * ( mu * ( 2 * 
( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( -1 * ( mu )**( 2 ) * ( mu * ( 2 
* ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) 
* ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu 
+ 12 * N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 
1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) )**( 2/3 ) ) ) ) )
    return eps3_LO

def eps4_LO(N):
    eps4_LO= -8 * ( mu )**( 2 ) * ( -12 * N * mu + ( -1 * ( 2 )**( 1/2 ) * 
mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( ( mu )**( 2 ) 
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + -1 * ( 2 )**( 1/2 ) 
* ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) 
+ -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) * ( ( ( 
mu )**( 2 ) + ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * 
mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * 
( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 
2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) )**( 
-1 ) * ( ( ( mu )**( 2 ) + ( -1 * mu * ( ( 12 * N * mu + ( ( ( 2 
)**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 
1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + 
-3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * 
mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) 
) )**( 1/3 ) + ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) 
* mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) 
* ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 
2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) ) )**( 
-2 ) * ( ( ( mu )**( 2 ) + ( mu * ( ( 12 * N * mu + ( ( ( 2 )**( 
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * 
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) 
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) 
)**( 1/3 ) + ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * 
mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * 
( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 
2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) ) )**( 
-2 ) * ( 12672 * ( N )**( 2 ) * ( mu )**( 3 ) + ( 352 * ( 2 )**( 
1/2 ) * ( mu )**( 4 ) + ( -528 * ( mu )**( 5 ) + ( 53 * ( mu )**( 7 ) 
+ ( 2112 * ( 2 )**( 1/2 ) * N * ( mu )**( 3 ) * ( mu * ( 2 * ( 2 
)**( 1/2 ) + mu ) )**( 1/2 ) + ( -2112 * N * ( mu )**( 4 ) * ( 
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 1056 * ( 2 )**( 1/2 ) 
* N * ( mu )**( 2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) 
+ ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 
1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) 
)**( 1/2 ) + ( 176 * ( mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu 
) )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 
2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * 
mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) + 
( -88 * ( 2 )**( 1/2 ) * ( mu )**( 3 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) 
+ mu ) )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 
2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) 
+ -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 
1/2 ) + ( 828 * N * ( mu )**( 4 ) * ( ( 12 * N * mu + ( ( ( 
2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) 
)**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 
) + -3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + 
-1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 
1/2 ) ) ) )**( 1/3 ) + ( 69 * ( 2 )**( 1/2 ) * ( mu )**( 4 ) * ( mu * 
( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) * ( ( 12 * N * mu + ( ( ( 
2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) 
)**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 
) + -3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + 
-1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 
1/2 ) ) ) )**( 1/3 ) + ( -69 * ( mu )**( 5 ) * ( mu * ( 2 * ( 2 )**( 
1/2 ) + mu ) )**( 1/2 ) * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + 
-1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * 
mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 1/3 
) + ( 69 * ( 2 )**( 1/2 ) * ( mu )**( 3 ) * ( ( mu )**( 2 ) * ( 72 * 
( N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) * ( ( 12 * N * mu + ( ( ( 2 )**( 
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * 
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) 
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) 
)**( 1/3 ) + ( 2592 * ( N )**( 2 ) * mu * ( ( 12 * N * mu + 
( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 
1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 
) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) 
)**( 1/2 ) ) ) )**( 2/3 ) + ( 72 * ( 2 )**( 1/2 ) * ( mu )**( 2 ) * ( 
( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 
* ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) 
* ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * 
N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) + ( -108 * ( mu )**( 3 
) * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu 
)**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 
6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) + ( 53 * ( mu )**( 
5 ) * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( 
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu 
)**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 
6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 
) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) + ( 432 * ( 2 )**( 
1/2 ) * N * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) * 
( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 
2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 
) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * 
N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) + ( -432 * N * ( 
mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) * ( ( 12 
* N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 
2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 
( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * N + 
( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) 
)**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) + ( 216 * ( 2 )**( 1/2 ) * 
N * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 
)**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * 
mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) * 
( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 
2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 
) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * 
N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) + ( 36 * ( mu * ( 2 * ( 
2 )**( 1/2 ) + mu ) )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N 
)**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 
( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 
1/2 ) ) ) )**( 1/2 ) * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 
* mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * 
mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu 
* ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 
) + -18 * ( 2 )**( 1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) 
)**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 
)**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * 
mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) * 
( ( 12 * N * mu + ( ( ( 2 )**( 1/2 ) + -1 * mu ) * mu * ( mu * ( 
2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 
) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * N * ( 6 * 
N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( 2/3 ) ) ) ) ) ) ) ) ) ) ) ) ) 
) ) ) ) ) ) ) ) ) * ( ( 3 * ( mu )**( 4 ) + ( 3 * mu * ( 12 * N 
+ ( 2 )**( 1/2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) * 
( ( 12 * N * mu + ( ( 2 )**( 1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 
1/2 ) + mu ) )**( 1/2 ) + ( -1 * ( mu )**( 2 ) * ( mu * ( 2 * ( 2 
)**( 1/2 ) + mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 
72 * ( N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 
* N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) 
+ mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) )**( 1/3 ) + ( 3 * ( 2 )**( 
1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( N )**( 2 ) + ( ( 2 * ( 2 )**( 
1/2 ) + -3 * mu ) * mu + 12 * N * ( ( 2 )**( 1/2 ) + -1 * mu ) * 
( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) * ( ( 12 
* N * mu + ( ( 2 )**( 1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) + ( -1 * ( mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) 
+ mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( 
N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) )**( 1/3 ) + -1 * ( mu )**( 2 ) 
* ( 3 * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) * ( ( 12 * 
N * mu + ( ( 2 )**( 1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) + ( -1 * ( mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) 
+ mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( 
N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) )**( 1/3 ) + -7 * ( ( 12 * 
N * mu + ( ( 2 )**( 1/2 ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) + ( -1 * ( mu )**( 2 ) * ( mu * ( 2 * ( 2 )**( 1/2 ) 
+ mu ) )**( 1/2 ) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( 72 * ( 
N )**( 2 ) + ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) * mu + 12 * 
N * ( ( 2 )**( 1/2 ) + -1 * mu ) * ( mu * ( 2 * ( 2 )**( 1/2 ) + 
mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) ) )**( 2/3 ) ) ) ) ) )**( -1 )
    return eps4_LO



#Comment if you want eps4_LO(N) equal to 0
#def eps4_LO(N):
#    eps4_LO=0 
#    return eps4_LO


#We usually set eps5_LO =0
def eps5_LO(N):
    eps5_LO=0 
    return eps5_LO

# %%
#definining deltaN_star = 55 efolds. It is the same choice we made in the numerical script.

deltaN_star = 55

# %%
#Referining the slow roll parameters at 3NLO with respect to the computed HFF at LO

def eps1(N):      
    eps1 = eps1_LO(N) - 1/3 * eps1_LO(N) * eps2_LO(N) - 1/9 * eps1_LO(N)**2 * eps2_LO(N) + 5/36 * eps1_LO(N) * eps2_LO(N)**2 + 1/9 * eps1_LO(N) * eps2_LO(N) * eps3_LO(N)
    return eps1

def eps2(N):      
    eps2 = eps2_LO(N) - 1/6 * eps2_LO(N)**2 - 1/3 * eps2_LO(N) * eps3_LO(N) - 1/6 * eps1_LO(N) * eps2_LO(N)**2 + 1/18 * eps2_LO(N)**3 - 1/9 * eps1_LO(N) * eps2_LO(N) * eps3_LO(N) + 5/18 * eps2_LO(N)**2 * eps3_LO(N) + 1/9 * eps2_LO(N) * eps3_LO(N)**2 + 1/9 * eps2_LO(N) * eps3_LO(N) * eps4_LO(N)
    return eps2

def eps3(N):      
    eps3 = eps3_LO(N) - 1/3 * eps2_LO(N) * eps3_LO(N) - 1/3 * eps3_LO(N) * eps4_LO(N) - 1/6 * eps1_LO(N) * eps2_LO(N)**2 - 1/3 * eps1_LO(N) * eps2_LO(N) * eps3_LO(N) + 1/6 * eps2_LO(N)**2 * eps3_LO(N) + 5/18 * eps2_LO(N) * eps3_LO(N)**2 - 1/9 * eps1_LO(N) * eps3_LO(N) * eps4_LO(N) + 5/18 * eps2_LO(N) * eps3_LO(N) * eps4_LO(N) + 1/9 * eps3_LO(N)**2 * eps4_LO(N) + 1/9 * eps3_LO(N) * eps4_LO(N)**2 + 1/9 * eps3_LO(N) * eps4_LO(N) * eps5_LO(N)
    return eps3

def eps4(N):      
    eps4 = eps4_LO(N) - 1/3 * eps2_LO(N) * eps3_LO(N) - 1/6 * eps2_LO(N) * eps4_LO(N) - 1/3 * eps4_LO(N) * eps5_LO(N)
    return eps4

# %%
#Values of the espilon at the pivot scale:

print('Value of eps_1(N*) at LO',eps1_LO(deltaN_star))
print('Value of eps_1(N*) at N3LO', eps1(deltaN_star))

print('Value of eps_2(N*) at LO',eps2_LO(deltaN_star))
print('Value of eps_2(N*) at N3LO',eps2(deltaN_star))

print('Value of eps_3(N*) at LO',eps3_LO(deltaN_star))
print('Value of eps_3(N*) at N3LO',eps3(deltaN_star))

print('Value of eps_4(N*) at LO',eps4_LO(deltaN_star))
print('Value of eps_4(N*) at N3LO',eps4(deltaN_star))
# Out:
# Value of eps_1(N*) at LO 0.0005424659484479611
# Value of eps_1(N*) at N3LO 0.000538193187384958
# Value of eps_2(N*) at LO 0.024010026699162006
# Value of eps_2(N*) at N3LO 0.02377475709474947
# Value of eps_3(N*) at LO 0.018056544427203326
# Value of eps_3(N*) at N3LO 0.01781040688385871
# Value of eps_4(N*) at LO 0.018088872419342598
# Value of eps_4(N*) at N3LO 0.01787197399645432

# %%
#Interval of integration in k. The same as the numerical script.

k_star= 0.05
k_num = 94
k_win = np.logspace(-5, 3, k_num)

# %% [markdown]
# ## Analytical PPS at first order

# %%
#Defining the Hubble function at the first order.

def H_sq1(mass,N):
    H_sq = 1/3 * (mass)**2 * ( ( 1 + 2 * mu * ( ( ( ( 12 * N * mu + ( ( ( 2 )**( \
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 \
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * \
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) \
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) \
)**( 1/3 ) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 \
) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + \
( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) \
* mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( \
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( \
-1/3 ) ) ) )**( -1 ) ) )**( -1 )
    return H_sq

# %%
#The P0s at the first order

P0_s1 = H_sq1(m2an_s,deltaN_star)/(8*np.pi**2 * Mpl**2 *  eps1(deltaN_star))

P0_t1 = 2*H_sq1(m2an_t,deltaN_star)/(np.pi**2 * Mpl**2)

# %%
#Defining the first order coefficients

C = -0.7296

def as01(N): 
    return 1-2*(C+1)*eps1(N) - C*eps2(N)

def as11(N): 
    return -2*eps1(N) - eps2(N) 

def as21(N):
    return 0

def at01(N):
    return 1-2*(C+1)*eps1(N) 

def at11(N):
    return -2*eps1(N)

def at21(N):
    return  0

# %%
#I order scalar PPS

def PS_s1(ka): 
    log = np.log(ka/k_star)
    PS_s_val1 = P0_s1*(as01(deltaN_star) + as11(deltaN_star)*log)
    return PS_s_val1

# %%
#I order scalar PPS plot

plt.loglog(k_win, PS_s1(k_win), label = "Scalar PPS") 
plt.xscale('log')
plt.yscale('log')
#plt.ylim([10**(-9), 10**(-8)])
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('I order analytical PPS for KKLT')
plt.legend()

# %%
#I order tensor power spectrum

def PS_t1(ka):
    log = np.log(ka/k_star)
    PS_t_val1  = P0_t1*(at01(deltaN_star) + at11(deltaN_star)*log)
    return PS_t_val1

# %%
#I order tensor PPS plot

plt.loglog(k_win, PS_t1(k_win), label = "Tensor PPS")
plt.xscale('log')
plt.yscale('log')
#plt.ylim([10**(-9), 10**(-8)])

plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('I order analytical tensor PPS for KKLT')
plt.legend()

# %%
#I order Scalar and tensor PPS plot

plt.loglog(k_win, PS_s1(k_win), label = "Scalar PPS")
plt.loglog(k_win, PS_t1(k_win),label = "Tensorial PPS")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R , h}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('I order analytical PPS')
plt.legend()

# %% [markdown]
# ## Analytical PPS at second order

# %%
#Defining the Hubble function at the second order
#(it is always the same at every order, we do it for the sake of completness)

def H_sq2(mass,N):
    H_sq2 = 1/3 * (mass)**2 * ( ( 1 + 2 * mu * ( ( ( ( 12 * N * mu + ( ( ( 2 )**( \
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 \
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * \
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) \
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) \
)**( 1/3 ) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 \
) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + \
( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) \
* mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( \
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( \
-1/3 ) ) ) )**( -1 ) ) )**( -1 )
    return H_sq2

# %%
#The P0s at the second order
#(they are always the same at every order, we do it for the sake of completness)

P0_s2 = H_sq2(m2an_s,deltaN_star)/(8*np.pi**2 * Mpl**2 *  eps1(deltaN_star))

P0_t2 = 2*H_sq2(m2an_t, deltaN_star)/(np.pi**2 * Mpl**2)

# %%
#Defining the a parameters at the second order 

C = -0.7296

def as02(N): 
    return 1-2*(C+1)*eps1(N) - C*eps2(N) + (2*C**2 +2*C + 0.5*np.pi**2 -3)*eps1(N)**2 + (C**2 - C + 7/12* np.pi**2 -6)*eps1(N)*eps2(N) + (0.5*C**2 + np.pi**2/8 -1)*eps2(N)**2 + (-0.5*C**2 + np.pi**2/24)*eps2(N)*eps3(N)

def as12(N): 
    return -2*eps1(N) - eps2(N) + 2*(2*C+1)*eps1(N)**2 + (2*C-1)*eps1(N)*eps2(N) + C*eps2(N)**2 - C*eps2(N)*eps3(N)

def as22(N):
    return 4*eps1(N)**2 +2*eps1(N)*eps2(N)+eps2(N)**2-eps2(N)*eps3(N)

def at02(N):
    return 1-2*(C+1)*eps1(N) + (2*C**2 +2*C + 0.5*np.pi**2 -3)*eps1(N)**2 + (-C**2 -2*C + np.pi**2/12 -2)*eps1(N)*eps2(N)

def at12(N):
    return -2*eps1(N) +2*(2*C+1)*eps1(N)**2- 2*(C+1)*eps1(N)*eps2(N)

def at22(N):
    return  4*eps1(N)**2 - 2*eps1(N)*eps2(N)

# %%
#Scalar PPS at the second order

def PS_s2(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    PS_s_val2  = P0_s2*(as02(deltaN_star) + as12(deltaN_star)*log + 0.5*as22(deltaN_star)*log_sq)
    return PS_s_val2

# %%
#II order scalar PPS plot

plt.loglog(k_win, PS_s2(k_win), label = "Scalar PPS")
plt.xscale('log')
plt.yscale('log')
#plt.ylim([10**(-9), 10**(-8)])
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('II order analytical scalar PPS for KKLT')
plt.legend()

# %%
#II order tensor PPS

def PS_t2(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    PS_t_val2  = P0_t2*(at02(deltaN_star) + at12(deltaN_star)*log + 0.5*at22(deltaN_star)*log_sq)
    return PS_t_val2

# %%
#II order tensor PPS plot

plt.loglog(k_win, PS_t2(k_win),label = "Tensor PPS")
plt.ylabel(r'$P_{h}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('II order analytical tensor PPS for KKLT' )
plt.legend()

# %%
#II order scalar and tensor PPS plots

plt.loglog(k_win, PS_s2(k_win), label = "Scalar PPS")
plt.loglog(k_win, PS_t2(k_win),label = "Tensorial PPS")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R , h}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('II order analytical PPS for KKLT')
plt.legend()

# %% [markdown]
# ## Analytical PPS at third order

# %% [markdown]
# We emphasize again that for the third-order PPS, we also consider the case with $\epsilon_4=0$. Consequently, the quantities defined at third order include a special flag that allows us to choose whether $\epsilon_4$ vanishes or not.

# %%
#Defining the Hubble function at the third order
#(it is always the same at every order, we do it for the sake of completness)

def H_sq3(mass,N):
    H_sq3 = 1/3 * (mass)**2 * ( ( 1 + 2 * mu * ( ( ( ( 12 * N * mu + ( ( ( 2 )**( \
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 \
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * \
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) \
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) \
)**( 1/3 ) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 \
) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + \
( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) \
* mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( \
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( \
-1/3 ) ) ) )**( -1 ) ) )**( -1 )
    return H_sq3

# %%
#The P0s at the third order
#(they are always the same at every order, we do it for the sake of completness)

P0_s3 = H_sq3(m2an_s,deltaN_star)/(8*np.pi**2 * Mpl**2 *  eps1(deltaN_star))

P0_s3_noep4 = H_sq3(m2an_s_noeps4,deltaN_star)/(8*np.pi**2 * Mpl**2 *  eps1(deltaN_star)) #

P0_t3 = 2*H_sq3(m2an_t, deltaN_star)/(np.pi**2 * Mpl**2)

# %%
#Defining the a parameters at the third order 
#The scalar coefficients are defined so that it is possible to set eps4(N) = 0

C = -0.7296


def as03(N, e4 = True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4 = 0
    return (1 - 2 * (1 + C) * eps1(N) + (-3 + 2 * C + 2 * C**2 + (np.pi**2) / 2) * eps1(N)**2 - C * eps2(N) + (-6 - C + C**2 + (7 * np.pi**2) / 12) * eps1(N) * eps2(N) + (1 / 8) * (-8 + 4 * C**2 + np.pi**2) * eps2(N)**2 + (1 / 24) * (-12 * C**2 + np.pi**2) * eps2(N) * eps3(N) - (1 / 24) * (-16 - 24 * C + 4 * C**3 + 3 * C * np.pi**2 + 2 * zeta(3)) * (8 * eps1(N)**3 + eps2(N)**3) + (1 / 12) * (72 * C + 36 * C**2 + 13 * np.pi**2 - 8 * C * np.pi**2 - 12 * zeta(3)) * eps1(N)**2 * eps2(N) - (1 / 24) * (16 - 24 * C - 12 * C**2 + 8 * C**3 - 15 * np.pi**2 + 6 * C * np.pi**2 + 28 * zeta(3)) * eps1(N) * eps2(N)**2 + (1 / 24) * (16 - 4 * C**3 + C * np.pi**2 - 8 * zeta(3)) * (eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4) + (1 / 24) * (-48 * C + 12 * C**3 + 5 * C * np.pi**2) * eps2(N)**2 * eps3(N) + (1 / 12) * (-8 - 72 * C - 12 * C**2 + 8 * C**3 + np.pi**2 + 6 * C * np.pi**2 - 8 * zeta(3)) * eps1(N) * eps2(N) * eps3(N))


def as13(N, e4= True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4 = 0
    return (-2 * eps1(N) + 2 * (2 * C + 1) * eps1(N)**2 - eps2(N) + (2 * C - 1) * eps1(N) * eps2(N) + C * eps2(N)**2 - C * eps2(N) * eps3(N)- (1 / 8) * (-8 + 4 * C**2 + np.pi**2) * (8 * eps1(N)**3 + eps2(N)**3) - (2 / 3) * (-9 - 9 * C + np.pi**2) * eps1(N)**2 * eps2(N) - (1 / 4) * (-4 - 4 * C + 4 * C**2 + np.pi**2) * eps1(N) * eps2(N)**2 + (1 / 2) * (-12 - 4 * C + 4 * C**2 + np.pi**2) * eps1(N) * eps2(N) * eps3(N) + (1 / 24) * (-12 * C**2 + np.pi**2) * (eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4) + (1 / 24) * (-48 + 36 * C**2 + 5 * np.pi**2) * eps2(N)**2 * eps3(N))


def as23(N, e4= True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4 = 0
    return  (4 * eps1(N)**2 + 2 * eps1(N) * eps2(N) + 6 * eps1(N)**2 * eps2(N) + eps2(N)**2 - eps2(N) * eps3(N)  + (1 - 2 * C) * (eps1(N) * eps2(N)**2 - 2 * eps1(N) * eps2(N) * eps3(N))- C * (8 * eps1(N)**3 + eps2(N)**3 - 3 * eps2(N)**2 * eps3(N) + eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4))


def as33(N, e4= True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4 = 0
    return (-8 * eps1(N)**3 - 2 * eps1(N) * eps2(N)**2 - eps2(N)**3 + 4 * eps1(N) * eps2(N) * eps3(N)  + 3 * eps2(N)**2 * eps3(N) - eps2(N) * eps3(N)**2 - eps2(N) * eps3(N) * epsi4)


def at03(N):
    return (1 + (-2 - 2 * C) * eps1(N) + (1 / 2) * (-6 + 4 * C + 4 * C**2 + np.pi**2) * eps1(N)**2   + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * eps1(N) * eps2(N) - (1 / 3) * (-16 - 24 * C + 4 * C**3 + 3 * C * np.pi**2 + 2 * zeta(3)) * eps1(N)**3  + (1 / 12) * (-96 - 72 * C + 36 * C**2 + 24 * C**3 + 13 * np.pi**2 + 10 * C * np.pi**2) * eps1(N)**2 * eps2(N)   - (1 / 12) * (8 + 24 * C + 12 * C**2 + 4 * C**3 - np.pi**2 - C * np.pi**2 + 8 * zeta(3)) * (eps1(N) * eps2(N)**2 + eps1(N) * eps2(N) * eps3(N)))

def at13(N):
    return  (-2 * eps1(N) + 2 * eps1(N)**2 + 4 * C * eps1(N)**2 + (-2 - 2 * C) * eps1(N) * eps2(N) - (-8 + 4 * C**2 + np.pi**2) * eps1(N)**3 + (1 / 6) * (-36 + 36 * C + 36 * C**2 + 5 * np.pi**2) * eps1(N)**2 * eps2(N) + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * (eps1(N) * eps2(N)**2 + eps1(N) * eps2(N) * eps3(N)))


def at23(N):
    return (4 * eps1(N)**2 - 8 * C * eps1(N)**3 - 2 * eps1(N) * eps2(N) + 2 * (3 + 6 * C) * eps1(N)**2 * eps2(N) - 2 * (C + 1) * (eps1(N) * eps2(N)**2 + 2 * eps1(N) * eps2(N) * eps3(N)))


def at33(N):
    return (-8 * eps1(N)**3 + 12 * eps1(N)**2 * eps2(N) - 2 * eps1(N) * eps2(N)**2 - 2 * eps1(N) * eps2(N) * eps3(N))

# %%
#Third order scalar PPS

def PS_s3(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    PS_s_val3  = P0_s3*(as03(deltaN_star) + as13(deltaN_star)*log + 0.5*as23(deltaN_star)*log_sq + (1/6)*as33(deltaN_star)*log_cub)
    return PS_s_val3

#Third order scalar PPS with eps4=0

def PS_s3_noeps4(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    PS_s_val3  = P0_s3_noep4*(as03(deltaN_star, False) + as13(deltaN_star,False)*log + 0.5*as23(deltaN_star,False)*log_sq + (1/6)*as33(deltaN_star,False)*log_cub)
    return PS_s_val3

# %%
#III order scalar PPS plot

plt.loglog(k_win, PS_s3(k_win), label = "Scalar PPS ")
plt.loglog(k_win, PS_s3_noeps4(k_win), label = "Scalar PPS with $\epsilon_4 =0$")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('III order analytical scalar PPS for KKLT')
plt.legend()

# %%
#III order tensor PPS

def PS_t3(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    PS_t_val3  = P0_t3*(at03(deltaN_star) + at13(deltaN_star)*log + 0.5*at23(deltaN_star)*log_sq+ (1/6)*at33(deltaN_star)*log_cub)
    return PS_t_val3

# %%
#III order tensor PPS plot

plt.loglog(k_win, PS_t3(k_win),label = "Tensor PPS")
plt.ylabel(r'$P_{h}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('III order analytical tensor PPS for KKLT' )
plt.legend()

# %%
#III order scalar and tensor PPS plots

plt.loglog(k_win, PS_s3(k_win), label = "Scalar PPS")
plt.loglog(k_win, PS_t3(k_win),label = "Tensorial PPS")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R , h}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.title('III order analytical PPS for KKLT')
plt.legend()

# %% [markdown]
# ## Comparisions among the PPS at different orders

# %%
#We compute the tensor-to-scalar ratio in two ways:

#1) as the effective ratio:
a= P0_t2
b =P0_s2
aa=P0_t1
bb=P0_s1
aaa=P0_t3
bbb=P0_s3

R = a/b
RR = aa/bb
RRR = aaa/bbb

#2) as 16*eps1(N_star)

R1= eps1(deltaN_star)*16

# %%
print("At first order R=",RR)
print("At second order R=",R)
print("At third order R=",RRR)
print("The ratio between R at first and second order is",R1/R)
print("Unsing 16eps1 we have R=",R1)
# Out:
# At first order R= 0.008611090998159328
# At second order R= 0.008611090998159328
# At third order R= 0.008611090998159328
# The ratio between R at first and second order is 1.0
# Unsing 16eps1 we have R= 0.008611090998159328

# %%
#Relative differences among the PPS at different orders:

error_s_21 = (PS_s2(k_win)/PS_s1(k_win)-1)*100
error_s_31 = (PS_s3(k_win)/PS_s1(k_win)-1)*100
error_s_32 = (PS_s3(k_win)/PS_s2(k_win)-1)*100

error_t_21 = (PS_t2(k_win)/PS_t1(k_win)-1)*100
error_t_31 = (PS_t3(k_win)/PS_t1(k_win)-1)*100
error_t_32 = (PS_t3(k_win)/PS_t2(k_win)-1)*100

# %%
#Scalar PPS errors plots

plt.plot(k_win, error_s_21, label = "II-I scalar PPS error")
plt.xscale('log')
plt.ylabel(r'$Error %$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

plt.plot(k_win, error_s_31, label = "III-I scalar PPS error")
plt.xscale('log')
plt.ylabel(r'$Error \%$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

plt.plot(k_win, error_s_32, label = "III-II scalar PPS error")
plt.xscale('log')
plt.ylabel(r'$Error \%$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#Tensor PPS errors plots

plt.plot(k_win, error_t_21, label = "II-I tensor PPS error")
plt.xscale('log')
plt.ylabel(r'$Error $')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

plt.plot(k_win, error_t_31, label = "III-I tensor PPS error")
plt.xscale('log')
plt.ylabel(r'$Error $')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

plt.plot(k_win, error_t_32, label = "III-II tensor PPS error")
plt.xscale('log')
plt.ylabel(r'$Error $')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#Scalar PPS at different orders

plt.loglog(k_win, PS_s1(k_win), label = "Scalar I")
plt.loglog(k_win, PS_s2(k_win), label = "Scalar II")
plt.loglog(k_win, PS_s3(k_win), label = "Scalar III")
plt.loglog(k_win, PS_s3_noeps4(k_win), label = "Scalar III with $\epsilon_4=0$")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#Tensor PPS at different orders

plt.loglog(k_win, PS_t1(k_win), label = "Tensor I")
plt.loglog(k_win, PS_t2(k_win), label = "Tensor II")
plt.loglog(k_win, PS_t3(k_win), label = "Tensor III")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{h}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %% [markdown]
# ## Analytical PPS with $b$ coefficients

# %% [markdown]
# Now we want to compute the scalar and tensor PPS again, but using their logarithmic expansion, i.e. using the $b_S$ and $b_T$ coefficients.

# %%
#Defining the b parameters at the first order 

def bs01(N):
    return -2*(C+1)*eps1(N) - C*eps2(N)

def bs11(N):
    return -2*eps1(N) - eps2(N) 

def bs21(N):
    return 0

def bt01(N): 
    return -2*(C+1)*eps1(N)

def bt11(N):
    return -2*eps1(N)

def bt21(N):
    return 0

# %%
#I order scalar PPS with b

def loggPS_s1(ka):
    log = np.log(ka/k_star)
    loggPS_s_val1 = P0_s1*np.exp((bs01(deltaN_star) + bs11(deltaN_star)*log))
    return loggPS_s_val1

# %%
#I order scalar PPS with a vs with b

plt.loglog(k_win, PS_s1(k_win), label = "Scalar PPS I with a ")
plt.loglog(k_win, loggPS_s1(k_win), label = "Scalar PPS I with b")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#I order tensor PPS with b

def loggPS_t1(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    loggPS_t_val1  = P0_t1*np.exp((bt01(deltaN_star) + bt11(deltaN_star)*log))
    return loggPS_t_val1

# %%
#I order tensor PPS with a vs with b

plt.loglog(k_win, PS_t1(k_win), label = "Tensor PPS I with a")
plt.loglog(k_win, loggPS_t1(k_win), label = "Tensor PPS I with b")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#Defining the b parameters at second order 

def bs02(N): 
    return -2*(C+1)*eps1(N) - C*eps2(N) + (-2*C + 0.5*np.pi**2 -5)*eps1(N)**2 + (-C**2 - 3*C + 7/12* np.pi**2 -6)*eps1(N)*eps2(N) + ( np.pi**2/8 -1)*eps2(N)**2 + (-0.5*C**2 + np.pi**2/24)*eps2(N)*eps3(N)

def bs12(N): 
    return -2*eps1(N) - eps2(N) + -2*eps1(N)**2 - (2*C+3)*eps1(N)*eps2(N)  - C*eps2(N)*eps3(N)

def bs22(N):
    return -2*eps1(N)*eps2(N)-eps2(N)*eps3(N)

def bt02(N):
    return -2*(C+1)*eps1(N) + (-2*C + 0.5*np.pi**2 -5)*eps1(N)**2 + (-C**2 -2*C + np.pi**2/12 -2)*eps1(N)*eps2(N)

def bt12(N):
    return -2*eps1(N) -2*eps1(N)**2- 2*(C+1)*eps1(N)*eps2(N)

def bt22(N):
    return - 2*eps1(N)*eps2(N)

# %%
#II order scalar PPS with b

def loggPS_s2(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    loggPS_s_val2  = P0_s2*np.exp((bs02(deltaN_star) + bs12(deltaN_star)*log + 0.5*bs22(deltaN_star)*log_sq))
    return loggPS_s_val2

# %%
#II order scalar PPS with a vs with b

plt.loglog(k_win, PS_s2(k_win), label = "Scalar PPS II with a")
plt.loglog(k_win, loggPS_s2(k_win), label = "Scalar PPS II with b")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#II order tensor PPS with b

def loggPS_t2(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    loggPS_t_val2  = P0_t2*np.exp((bt02(deltaN_star) + bt12(deltaN_star)*log + 0.5*bt22(deltaN_star)*log_sq))
    return loggPS_t_val2

# %%
#II order tensor PPS with a vs with b

plt.loglog(k_win, PS_t2(k_win), label = "Tensor PPS II with a")
plt.loglog(k_win, loggPS_t2(k_win), label = "Tensor PPS II with b")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#Defining the b parameters at the third order 
#The scalar coefficients are defined so that it is possible to set eps4(N) = 0


def bs03(N, e4=True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4=0
    return (-2 * (1 + C) * eps1(N) + (-5 - 2 * C + (np.pi**2) / 2) * eps1(N)**2 - C * eps2(N) + (-6 - 3 * C - C**2 + (7 * np.pi**2) / 12) * eps1(N) * eps2(N)+ (1 / 24) * (-12 * C**2 + np.pi**2) * eps2(N) * eps3(N) - (1 / 24) * (80 + 48 * C - 24 * np.pi**2 + 16 * zeta(3)) * eps1(N)**3 + (1 / 8) * (-8 + np.pi**2) * eps2(N)**2  - (1 / 24) * (-16 + 2 * zeta(3)) * eps2(N)**3 + (1 / 12) * (-144 - 180 * C - 36 * C**2 + 27 * np.pi**2 + 12 * C * np.pi**2 - 12 * zeta(3)) * eps1(N)**2 * eps2(N)- (1 / 24) * (64 + 168 * C + 36 * C**2 + 8 * C**3 - 21 * np.pi**2 - 14 * C * np.pi**2 + 28 * zeta(3)) * eps1(N) * eps2(N)**2+ (1 / 24) * (16 - 4 * C**3 + C * np.pi**2 - 8 * zeta(3)) * (eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4)  + (1 / 24) * (-48 * C + 6 * C * np.pi**2) * eps2(N)**2 * eps3(N)+ (1 / 12) * (-8 - 72 * C - 24 * C**2 - 4 * C**3 + 2 * np.pi**2 + 7 * C * np.pi**2 - 8 * zeta(3)) * eps1(N) * eps2(N) * eps3(N))


def bs13(N, e4=True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4=0
    return (-2 * eps1(N) - 2 * eps1(N)**2 - 2 * eps1(N)**3 - eps2(N) - (3 + 2 * C) * eps1(N) * eps2(N) - C * eps2(N) * eps3(N) - (2 / 3) * (45 / 2 + 9 * C - 3 * np.pi**2 / 2) * eps1(N)**2 * eps2(N)- (1 / 4) * (28 + 12 * C + 4 * C**2 - 7 * np.pi**2 / 3) * eps1(N) * eps2(N)**2 + (1 / 2) * (-12 - 8 * C - 2 * C**2 + 7 * np.pi**2 / 6) * eps1(N) * eps2(N) * eps3(N)+ (1 / 24) * (-12 * C**2 + np.pi**2) * (eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4) + (1 / 24) * (-48 + 6 * np.pi**2) * eps2(N)**2 * eps3(N))


def bs23(N, e4=True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4=0
    return (-2 * eps1(N) * eps2(N) - 6 * eps1(N)**2 * eps2(N) - (3 + 2 * C) * eps1(N) * eps2(N)**2 - eps2(N) * eps3(N)- 2 * (2 + C) * eps1(N) * eps2(N) * eps3(N) - C * eps2(N) * eps3(N)**2 - C * eps2(N) * eps3(N) * epsi4)


def bs33(N, e4=True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4=0
    return  (-2 * eps1(N) * eps2(N)**2 - 2 * eps1(N) * eps2(N) * eps3(N) - eps2(N) * eps3(N)**2 - eps2(N) * eps3(N) * epsi4)


def bt03(N):
    return (-2 * (1 + C) * eps1(N) + (1 / 2) * (-10 - 4 * C + np.pi**2) * eps1(N)**2  + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * eps1(N) * eps2(N) - (1 / 3) * (10 + 6 * C - 3 * np.pi**2 + 2 * zeta(3)) * eps1(N)**3  + (1 / 12) * (-144 - 168 * C - 36 * C**2 + 15 * np.pi**2 + 12 * C * np.pi**2) * eps1(N)**2 * eps2(N) - (1 / 12) * (8 + 24 * C + 12 * C**2 + 4 * C**3 - np.pi**2 - C * np.pi**2 + 8 * zeta(3)) * (eps1(N) * eps2(N)**2 + eps1(N) * eps2(N) * eps3(N)))


def bt13(N):
    return (-2 * eps1(N) - 2 * eps1(N)**2 + (-2 - 2 * C) * eps1(N) * eps2(N) - 2 * eps1(N)**3  + (1 / 6) * (-84 - 36 * C + 6 * np.pi**2) * eps1(N)**2 * eps2(N) + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * (eps1(N) * eps2(N)**2 + eps1(N) * eps2(N) * eps3(N)))


def bt23(N):
    return (-2 * eps1(N) * eps2(N) - 6 * eps1(N)**2 * eps2(N) - 2 * (1 + C) * eps1(N) * eps2(N)**2 - 2 * (1 + C) * eps1(N) * eps2(N) * eps3(N))

def bt33(N):
    return (-2 * eps1(N) * eps2(N)**2 - 2 * eps1(N) * eps2(N) * eps3(N))

# %%
#III order scalar PPS with b

def loggPS_s3(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_s_val3  = P0_s3*np.exp((bs03(deltaN_star) + bs13(deltaN_star)*log + 0.5*bs23(deltaN_star)*log_sq+(1/6)*bs33(deltaN_star)*log_cub))
    return loggPS_s_val3

#III order scalar PPS with b with epsilon_4=0

def loggPS_s3_noeps4(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_s_val3  = P0_s3_noep4*np.exp((bs03(deltaN_star, False) + bs13(deltaN_star, False)*log + 0.5*bs23(deltaN_star, False)*log_sq+(1/6)*bs33(deltaN_star, False)*log_cub))
    return loggPS_s_val3

# %%
#III order scalar PPS with a vs with b

plt.loglog(k_win, PS_s3(k_win), label = "III order scalar PPS with a")
plt.loglog(k_win, PS_s3_noeps4(k_win), label = "III order scalar PPS with a with $\epsilon_4=0$")
plt.loglog(k_win, loggPS_s3(k_win), label = "III order scalar PPS with b")
plt.loglog(k_win, loggPS_s3_noeps4(k_win), label = "III order scalar PPS with b with $\epsilon_4=0$")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#III order tensor PPS with b

def loggPS_t3(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_t_val3  = P0_t2*np.exp((bt03(deltaN_star) + bt13(deltaN_star)*log + 0.5*bt23(deltaN_star)*log_sq+(1/6)*bt33(deltaN_star)*log_cub))
    return loggPS_t_val3

# %%
#III order tensor PPS with a vs with b

plt.loglog(k_win, PS_t3(k_win), label = "III ord. tensor PPS with a")
plt.loglog(k_win, loggPS_t3(k_win), label = "III ord. tensor PPS with b")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %% [markdown]
# # Spectral indices, their runnings, and the runnings of the runnings

# %% [markdown]
# Here we compute analytically, i.e. using the $b$ coefficients, the spectral indices $n_S$ and $n_T$, their runnings $\alpha_S$ and $\alpha_T$, and the runnings of the runnings $\beta_S$ and $\beta_T$. We directly use the third order PPS.

# %%
# n_S and n_T at third order

def n_s3_ana(ka): 
    log = np.log(ka/k_star)
    log_sq= log**2
    n_s3_value = 1+bs13(deltaN_star)+  bs23(deltaN_star)*log + 0.5*bs33(deltaN_star)*log**2 
    return n_s3_value

def n_s3_ana_noesp4(ka): 
    log = np.log(ka/k_star)
    log_sq= log**2
    n_s3_value = 1+bs13(deltaN_star,False)+  bs23(deltaN_star,False)*log + 0.5*bs33(deltaN_star,False)*log**2 
    return n_s3_value

def n_t3_ana(ka): 
    log = np.log(ka/k_star)
    log_sq= log**2
    n_t3_value = bt13(deltaN_star)+  bt23(deltaN_star)*log + 0.5*bt33(deltaN_star)*log**2 
    return n_t3_value

# %%
# n_S plots

plt.loglog(k_win, n_s3_ana(k_win), label = "$n_S$")
plt.loglog(k_win, n_s3_ana_noesp4(k_win), label = "$n_S$ with $\epsilon_4=0$")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$n_S$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#n_T plot

plt.plot(k_win, n_t3_ana(k_win), label = "$n_T$")
plt.xscale('log')
plt.ylabel(r'$n_T$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
# alpha_S and alpha_T at third order

def alpha_s3_ana(ka): 
    log = np.log(ka/k_star)
    alpha_s3_value = bs23(deltaN_star) + bs33(deltaN_star)*log 
    return alpha_s3_value

def alpha_s3_ana_noesp4(ka): 
    log = np.log(ka/k_star)
    alpha_s3_value = bs23(deltaN_star,False) + bs33(deltaN_star,False)*log 
    return alpha_s3_value

def alpha_t3_ana(ka): 
    log = np.log(ka/k_star)
    alpha_t3_value = bt23(deltaN_star) + bt33(deltaN_star)*log
    return alpha_t3_value

# %%
#alpha_S plots

plt.plot(k_win, alpha_s3_ana(k_win), label=r"$\alpha_S$")
plt.plot(k_win, alpha_s3_ana_noesp4(k_win), label=r"$\alpha_S$ with $\epsilon_4=0$")
plt.xscale('log')
plt.ylabel(r'$\alpha_S$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#alpha_T plots

plt.plot(k_win, alpha_t3_ana(k_win), label=r"$\alpha_T$")
plt.xscale('log')
plt.ylabel(r'$\alpha_T$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#beta_S and beta_T 

beta_s3_ana = bs33(deltaN_star)
beta_s3_ana_noeps4 = bs33(deltaN_star,False)
beta_t3_ana = bt33(deltaN_star)

# %%
print("n_S(k_star) =", n_s3_ana(k_star))
print("n_T(k_star) =", n_t3_ana(k_star))
print("alpha_S(k_star) =", alpha_s3_ana(k_star))
print("alpha_T(k_star) =", alpha_t3_ana(k_star))
print("beta_S(k_star) =", beta_s3_ana)
print("beta_T(k_star) =", beta_t3_ana)
# Out:
# n_S(k_star) = 0.9754450086909621
# n_T(k_star) = -0.0010840174172132534
# alpha_S(k_star) = -0.00043909426027217356
# alpha_T(k_star) = -2.5919902334170233e-05
# beta_S(k_star) = -1.617347810881029e-05
# beta_T(k_star) = -1.0641986373493096e-06

# %% [markdown]
# # Computation of the coupling constant

# %% [markdown]
# Here, we compute the coupling constant for the analytical PPS by imposing that the scalar PPS at the pivot scale must have the value $2 \times 10^{-9}$.
#
# In this case, we do not distinguish between the scalar and tensor coupling constants. We only find two different coupling constants for the ordinary third order and the third order with $\epsilon_4=0$.
#
# Given that $\mathscr{P}_{R}(k_*) = a_0 \mathscr{P}_{0R}(k_*) = 2\times 10^{-9}$, by making $\mathscr{P}_{0R}(k_*)$ explicit, we can derive the relation for the coupling constant, which reads in this case as:
#
# $$ m^2 = \sqrt{\frac{8 \pi^2 \epsilon_1(N_*)(2\times 10^{-9})}{a_{S3}(N_*) \tilde{H}^2}}, $$
#
# where $\tilde{H}$ is the Hubble function defined without the coupling constant.

# %%
#As said at beginning we want PS(k_*) = 2e-9, then from the equation of P_S(k_*): 

def H_sq1_withoutmass(N):
    H_sq_withoutmass = 1/3  * ( ( 1 + 2 * mu * ( ( ( ( 12 * N * mu + ( ( ( 2 )**( \
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 \
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * \
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) \
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) \
)**( 1/3 ) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 \
) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + \
( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) \
* mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( \
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( \
-1/3 ) ) ) )**( -1 ) ) )**( -1 )
    return H_sq_withoutmass

mass_sqrd = np.sqrt( (8*np.pi**2 * eps1(deltaN_star)*2e-9)/(as03(deltaN_star)* H_sq1_withoutmass(deltaN_star)) )
print('mass squared = ',mass_sqrd) #You can set this coupling constant both for scalar and tensor analytical. 

mass_sqrd_noep4 = np.sqrt( (8*np.pi**2 * eps1(deltaN_star)*2e-9)/(as03(deltaN_star, False)* H_sq1_withoutmass(deltaN_star)) )
print('mass squared without eps4 = ',mass_sqrd_noep4) #You can set this coupling constant both for scalar and tensor analytical. 

#If the model forsees for a value of P_T(k_*),compute the coupling constant by 
#using the formula which relates P_T(k_*) to H^2.
# Out:
# mass squared =  1.733184509641672e-05
# mass squared without eps4 =  1.733184707364208e-05

# %% [markdown]
# # Third order PPS at LO vs NLO

# %% [markdown]
# Here we want to compute the third order PPS using $\varepsilon_i^{LO}$ and $\varepsilon_i^{NLO}$ and compare them. By changing $\varepsilon_i$ from LO to N3LO, the coupling costant of the model changes as well. This means the normalization factor changes and it is not possibile to compare the tensor PPS in this case. By renormalizing with a different mass the LO we are able to compare the scalar PSS, while we aspect the tensor PPS to be different.

# %%
#Renormalization at LO

#As said at beginning we want PS(k_*) = 2e-9, then from the equation of P_S(k_*): 

def H_sq1_withoutmass(N):
    H_sq_withoutmass = 1/3  * ( ( 1 + 2 * mu * ( ( ( ( 12 * N * mu + ( ( ( 2 )**( \
1/2 ) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 \
) + ( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * \
mu ) * mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) \
* ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) \
)**( 1/3 ) + mu * ( -1 + mu * ( ( 12 * N * mu + ( ( ( 2 )**( 1/2 \
) + -1 * mu ) * mu * ( mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) + \
( 2 )**( 1/2 ) * ( ( mu )**( 2 ) * ( ( 2 * ( 2 )**( 1/2 ) + -3 * mu ) \
* mu + 12 * N * ( 6 * N + ( ( 2 )**( 1/2 ) + -1 * mu ) * ( \
mu * ( 2 * ( 2 )**( 1/2 ) + mu ) )**( 1/2 ) ) ) )**( 1/2 ) ) ) )**( \
-1/3 ) ) ) )**( -1 ) ) )**( -1 )
    return H_sq_withoutmass

def as03_LO(N, e4_LO = True):
    if e4_LO:
        epsi4_LO = eps4_LO(N)
    else:
        epsi4_LO = 0
    return (1 - 2 * (1 + C) * eps1_LO(N) + (-3 + 2 * C + 2 * C**2 + (np.pi**2) / 2) * eps1_LO(N)**2 - C * eps2_LO(N) + (-6 - C + C**2 + (7 * np.pi**2) / 12) * eps1_LO(N) * eps2_LO(N) + (1 / 8) * (-8 + 4 * C**2 + np.pi**2) * eps2_LO(N)**2 + (1 / 24) * (-12 * C**2 + np.pi**2) * eps2_LO(N) * eps3_LO(N) - (1 / 24) * (-16 - 24 * C + 4 * C**3 + 3 * C * np.pi**2 + 14 * zeta(3)) * (8 * eps1_LO(N)**3 + eps2_LO(N)**3) + (1 / 12) * (72 * C + 36 * C**2 + 13 * np.pi**2 - 8 * C * np.pi**2 - 84 * zeta(3)) * eps1_LO(N)**2 * eps2_LO(N) - (1 / 24) * (16 - 24 * C - 12 * C**2 + 8 * C**3 - 15 * np.pi**2 + 6 * C * np.pi**2 + 100 * zeta(3)) * eps1_LO(N) * eps2_LO(N)**2 + (1 / 24) * (16 - 4 * C**3 + C * np.pi**2 - 8 * zeta(3)) * (eps2_LO(N) * eps3_LO(N)**2 + eps2_LO(N) * eps3_LO(N) * epsi4_LO) + (1 / 24) * (-48 * C + 12 * C**3 + 5 * C * np.pi**2) * eps2_LO(N)**2 * eps3_LO(N) + (1 / 12) * (-8 - 72 * C - 12 * C**2 + 8 * C**3 + np.pi**2 + 6 * C * np.pi**2 - 8 * zeta(3)) * eps1_LO(N) * eps2_LO(N) * eps3_LO(N))


mass_sqrd_LO = np.sqrt( (8*np.pi**2 * eps1_LO(deltaN_star)*2e-9)/(as03_LO(deltaN_star)* H_sq1_withoutmass(deltaN_star)) )
print('mass squared = ',mass_sqrd_LO) #You can set this coupling constant both for scalar and tensor analytical. 

mass_sqrd_noep4_LO = np.sqrt( (8*np.pi**2 * eps1_LO(deltaN_star)*2e-9)/(as03_LO(deltaN_star, False)* H_sq1_withoutmass(deltaN_star)) )
print('mass squared without eps4 = ',mass_sqrd_noep4_LO) #You can set this coupling constant both for scalar and tensor analytical. 

#If the model forsees for a value of P_T(k_*),compute the coupling constant by 
#using the formula which relates P_T(k_*) to H^2.
# Out:
# mass squared =  1.7399076640210377e-05
# mass squared without eps4 =  1.739907869677529e-05

# %%
#Defining the b parameters at the third order 
#The scalar coefficients are defined so that it is possible to set eps4(N) = 0


def bs03_LO(N, e4_LO=True):
    if e4_LO:
        epsi4_LO = eps4_LO(N)
    else:
        epsi4_LO=0
    return (-2 * (1 + C) * eps1_LO(N) + (-5 - 2 * C + (np.pi**2) / 2) * eps1_LO(N)**2 - C * eps2_LO(N) + (-6 - 3 * C - C**2 + (7 * np.pi**2) / 12) * eps1_LO(N) * eps2_LO(N)+ (1 / 24) * (-12 * C**2 + np.pi**2) * eps2_LO(N) * eps3_LO(N) - (1 / 24) * (80 + 48 * C - 24 * np.pi**2 + 112 * zeta(3)) * eps1_LO(N)**3 + (1 / 8) * (-8 + np.pi**2) * eps2_LO(N)**2  - (1 / 24) * (-16 + 14 * zeta(3)) * eps2_LO(N)**3 + (1 / 12) * (-144 - 180 * C - 36 * C**2 + 27 * np.pi**2 + 12 * C * np.pi**2 - 84 * zeta(3)) * eps1_LO(N)**2 * eps2_LO(N)- (1 / 24) * (64 + 168 * C + 36 * C**2 + 8 * C**3 - 21 * np.pi**2 - 14 * C * np.pi**2 + 100 * zeta(3)) * eps1_LO(N) * eps2_LO(N)**2+ (1 / 24) * (16 - 4 * C**3 + C * np.pi**2 - 8 * zeta(3)) * (eps2_LO(N) * eps3_LO(N)**2 + eps2_LO(N) * eps3_LO(N) * epsi4_LO)  + (1 / 24) * (-48 * C + 6 * C * np.pi**2) * eps2_LO(N)**2 * eps3_LO(N)+ (1 / 12) * (-8 - 72 * C - 24 * C**2 - 4 * C**3 + 2 * np.pi**2 + 7 * C * np.pi**2 - 8 * zeta(3)) * eps1_LO(N) * eps2_LO(N) * eps3_LO(N))


def bs13_LO(N, e4_LO=True):
    if e4_LO:
        epsi4_LO = eps4_LO(N)
    else:
        epsi4_LO=0
    return (-2 * eps1_LO(N) - 2 * eps1_LO(N)**2 - 2 * eps1_LO(N)**3 - eps2_LO(N) - (3 + 2 * C) * eps1_LO(N) * eps2_LO(N) - C * eps2_LO(N) * eps3_LO(N) - (2 / 3) * (45 / 2 + 9 * C - 3 * np.pi**2 / 2) * eps1_LO(N)**2 * eps2_LO(N)- (1 / 4) * (28 + 12 * C + 4 * C**2 - 7 * np.pi**2 / 3) * eps1_LO(N) * eps2_LO(N)**2 + (1 / 2) * (-12 - 8 * C - 2 * C**2 + 7 * np.pi**2 / 6) * eps1_LO(N) * eps2_LO(N) * eps3_LO(N)+ (1 / 24) * (-12 * C**2 + np.pi**2) * (eps2_LO(N) * eps3_LO(N)**2 + eps2_LO(N) * eps3_LO(N) * epsi4_LO) + (1 / 24) * (-48 + 6 * np.pi**2) * eps2_LO(N)**2 * eps3_LO(N))


def bs23_LO(N, e4_LO=True):
    if e4_LO:
        epsi4_LO = eps4_LO(N)
    else:
        epsi4_LO=0
    return (-2 * eps1_LO(N) * eps2_LO(N) - 6 * eps1_LO(N)**2 * eps2_LO(N) - (3 + 2 * C) * eps1_LO(N) * eps2_LO(N)**2 - eps2_LO(N) * eps3_LO(N)- 2 * (2 + C) * eps1_LO(N) * eps2_LO(N) * eps3_LO(N) - C * eps2_LO(N) * eps3_LO(N)**2 - C * eps2_LO(N) * eps3_LO(N) * epsi4_LO)


def bs33_LO(N, e4_LO=True):
    if e4_LO:
        epsi4_LO = eps4_LO(N)
    else:
        epsi4_LO=0
    return  (-2 * eps1_LO(N) * eps2_LO(N)**2 - 2 * eps1_LO(N) * eps2_LO(N) * eps3_LO(N) - eps2_LO(N) * eps3_LO(N)**2 - eps2_LO(N) * eps3_LO(N) * epsi4_LO)


def bt03_LO(N):
    return (-2 * (1 + C) * eps1_LO(N) + (1 / 2) * (-10 - 4 * C + np.pi**2) * eps1_LO(N)**2  + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * eps1_LO(N) * eps2_LO(N) - (1 / 3) * (10 + 6 * C - 3 * np.pi**2 + 14 * zeta(3)) * eps1_LO(N)**3  + (1 / 12) * (-144 - 168 * C - 36 * C**2 + 15 * np.pi**2 + 12 * C * np.pi**2) * eps1_LO(N)**2 * eps2_LO(N) - (1 / 12) * (8 + 24 * C + 12 * C**2 + 4 * C**3 - np.pi**2 - C * np.pi**2 + 8 * zeta(3)) * (eps1_LO(N) * eps2_LO(N)**2 + eps1_LO(N) * eps2_LO(N) * eps3_LO(N)))


def bt13_LO(N):
    return (-2 * eps1_LO(N) - 2 * eps1_LO(N)**2 + (-2 - 2 * C) * eps1_LO(N) * eps2_LO(N) - 2 * eps1_LO(N)**3  + (1 / 6) * (-84 - 36 * C + 6 * np.pi**2) * eps1_LO(N)**2 * eps2_LO(N) + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * (eps1_LO(N) * eps2_LO(N)**2 + eps1_LO(N) * eps2_LO(N) * eps3_LO(N)))


def bt23_LO(N):
    return (-2 * eps1_LO(N) * eps2_LO(N) - 6 * eps1_LO(N)**2 * eps2_LO(N) - 2 * (1 + C) * eps1_LO(N) * eps2_LO(N)**2 - 2 * (1 + C) * eps1_LO(N) * eps2_LO(N) * eps3_LO(N))

def bt33_LO(N):
    return (-2 * eps1_LO(N) * eps2_LO(N)**2 - 2 * eps1_LO(N) * eps2_LO(N) * eps3_LO(N))

# %%
#The P0s at the third order
#(they are always the same at every order, we do it for the sake of completness)

P0_s3_LO = H_sq3(m2an_s_LO,deltaN_star)/(8*np.pi**2 * Mpl**2 *  eps1_LO(deltaN_star))

P0_s3_noep4_LO = H_sq3(m2an_s_noeps4_LO,deltaN_star)/(8*np.pi**2 * Mpl**2 *  eps1_LO(deltaN_star)) #

P0_t3_LO = 2*H_sq3(m2an_t_LO, deltaN_star)/(np.pi**2 * Mpl**2)

# %%
#III order scalar PPS with b

def loggPS_s3_LO(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_s_val3_LO  = P0_s3_LO*np.exp((bs03_LO(deltaN_star) + bs13_LO(deltaN_star)*log + 0.5*bs23_LO(deltaN_star)*log_sq+(1/6)*bs33_LO(deltaN_star)*log_cub))
    return loggPS_s_val3_LO

#III order scalar PPS with b with epsilon_4=0

def loggPS_s3_noeps4_LO(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_s_val3_LO  = P0_s3_noep4_LO*np.exp((bs03_LO(deltaN_star, False) + bs13_LO(deltaN_star, False)*log + 0.5*bs23_LO(deltaN_star, False)*log_sq+(1/6)*bs33_LO(deltaN_star, False)*log_cub))
    return loggPS_s_val3_LO

# %%
#III order tensor PPS with b

def loggPS_t3_LO(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_t_val3_LO  = P0_t3_LO*np.exp((bt03_LO(deltaN_star) + bt13_LO(deltaN_star)*log + 0.5*bt23_LO(deltaN_star)*log_sq+(1/6)*bt33_LO(deltaN_star)*log_cub))
    return loggPS_t_val3_LO

# %%
#III order scalar PPS at LO vs at N3LO

plt.loglog(k_win, loggPS_s3_LO(k_win), label = "III order scalar PPS at LO")
plt.loglog(k_win, loggPS_s3(k_win), label = "III order scalar PPS at N3LO")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#Percentage error PPS using eps at LO vs PPS using eps at N3LO: 

error_s_LO_N3LO = (loggPS_s3(k_win)/loggPS_s3_LO(k_win)-1)*100


plt.loglog(k_win, error_s_LO_N3LO, label = "$\%P_{\cal R}$ LO vs N3LO ")
plt.xscale('log')
plt.yscale('linear')
plt.ylabel(r'$\%P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#III order tensor PPS with a vs with b

plt.loglog(k_win, loggPS_t3_LO(k_win), label = "III ord. tensor PPS at LO")
plt.loglog(k_win, loggPS_t3(k_win), label = "III ord. tensor PPS at N3LO")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{T}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %% [markdown]
# # Our spectra vs Auclair and Ringeval

# %% [markdown]
# Here we want to make the comparison between our solution and the one found by Auclair and Ringeval. They differs in $a_{S/T0}$ and $b_{S/T0}$ (see at beginning of the notebook).

# %%
#Defining the PPS's quantities as found by Auclair and Ringeval: 

def as03_AR(N, e4 = True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4 = 0
    return (1 - 2 * (1 + C) * eps1(N) + (-3 + 2 * C + 2 * C**2 + (np.pi**2) / 2) * eps1(N)**2 - C * eps2(N) + (-6 - C + C**2 + (7 * np.pi**2) / 12) * eps1(N) * eps2(N) + (1 / 8) * (-8 + 4 * C**2 + np.pi**2) * eps2(N)**2 + (1 / 24) * (-12 * C**2 + np.pi**2) * eps2(N) * eps3(N) - (1 / 24) * (-16 - 24 * C + 4 * C**3 + 3 * C * np.pi**2 + 14 * zeta(3)) * (8 * eps1(N)**3 + eps2(N)**3) + (1 / 12) * (72 * C + 36 * C**2 + 13 * np.pi**2 - 8 * C * np.pi**2 - 84 * zeta(3)) * eps1(N)**2 * eps2(N) - (1 / 24) * (16 - 24 * C - 12 * C**2 + 8 * C**3 - 15 * np.pi**2 + 6 * C * np.pi**2 + 100 * zeta(3)) * eps1(N) * eps2(N)**2 + (1 / 24) * (16 - 4 * C**3 + C * np.pi**2 - 8 * zeta(3)) * (eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4) + (1 / 24) * (-48 * C + 12 * C**3 + 5 * C * np.pi**2) * eps2(N)**2 * eps3(N) + (1 / 12) * (-8 - 72 * C - 12 * C**2 + 8 * C**3 + np.pi**2 + 6 * C * np.pi**2 - 8 * zeta(3)) * eps1(N) * eps2(N) * eps3(N))

def at03_AR(N):
    return (1 + (-2 - 2 * C) * eps1(N) + (1 / 2) * (-6 + 4 * C + 4 * C**2 + np.pi**2) * eps1(N)**2   + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * eps1(N) * eps2(N) - (1 / 3) * (-16 - 24 * C + 4 * C**3 + 3 * C * np.pi**2 + 14 * zeta(3)) * eps1(N)**3  + (1 / 12) * (-96 - 72 * C + 36 * C**2 + 24 * C**3 + 13 * np.pi**2 + 10 * C * np.pi**2) * eps1(N)**2 * eps2(N)   - (1 / 12) * (8 + 24 * C + 12 * C**2 + 4 * C**3 - np.pi**2 - C * np.pi**2 + 8 * zeta(3)) * (eps1(N) * eps2(N)**2 + eps1(N) * eps2(N) * eps3(N)))

def bs03_AR(N, e4=True):
    if e4:
        epsi4 = eps4(N)
    else:
        epsi4=0
    return (-2 * (1 + C) * eps1(N) + (-5 - 2 * C + (np.pi**2) / 2) * eps1(N)**2 - C * eps2(N) + (-6 - 3 * C - C**2 + (7 * np.pi**2) / 12) * eps1(N) * eps2(N)+ (1 / 24) * (-12 * C**2 + np.pi**2) * eps2(N) * eps3(N) - (1 / 24) * (80 + 48 * C - 24 * np.pi**2 + 112 * zeta(3)) * eps1(N)**3 + (1 / 8) * (-8 + np.pi**2) * eps2(N)**2  - (1 / 24) * (-16 + 14 * zeta(3)) * eps2(N)**3 + (1 / 12) * (-144 - 180 * C - 36 * C**2 + 27 * np.pi**2 + 12 * C * np.pi**2 - 84 * zeta(3)) * eps1(N)**2 * eps2(N)- (1 / 24) * (64 + 168 * C + 36 * C**2 + 8 * C**3 - 21 * np.pi**2 - 14 * C * np.pi**2 + 100 * zeta(3)) * eps1(N) * eps2(N)**2+ (1 / 24) * (16 - 4 * C**3 + C * np.pi**2 - 8 * zeta(3)) * (eps2(N) * eps3(N)**2 + eps2(N) * eps3(N) * epsi4)  + (1 / 24) * (-48 * C + 6 * C * np.pi**2) * eps2(N)**2 * eps3(N)+ (1 / 12) * (-8 - 72 * C - 24 * C**2 - 4 * C**3 + 2 * np.pi**2 + 7 * C * np.pi**2 - 8 * zeta(3)) * eps1(N) * eps2(N) * eps3(N))

def bt03_AR(N):
    return (-2 * (1 + C) * eps1(N) + (1 / 2) * (-10 - 4 * C + np.pi**2) * eps1(N)**2  + (1 / 12) * (-24 - 24 * C - 12 * C**2 + np.pi**2) * eps1(N) * eps2(N) - (1 / 3) * (10 + 6 * C - 3 * np.pi**2 + 14 * zeta(3)) * eps1(N)**3  + (1 / 12) * (-144 - 168 * C - 36 * C**2 + 15 * np.pi**2 + 12 * C * np.pi**2) * eps1(N)**2 * eps2(N) - (1 / 12) * (8 + 24 * C + 12 * C**2 + 4 * C**3 - np.pi**2 - C * np.pi**2 + 8 * zeta(3)) * (eps1(N) * eps2(N)**2 + eps1(N) * eps2(N) * eps3(N)))


def PS_s3_AR(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    PS_s_val3  = P0_s3*(as03_AR(deltaN_star) + as13(deltaN_star)*log + 0.5*as23(deltaN_star)*log_sq + (1/6)*as33(deltaN_star)*log_cub)
    return PS_s_val3

def PS_t3_AR(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    PS_t_val3  = P0_t3*(at03_AR(deltaN_star) + at13(deltaN_star)*log + 0.5*at23(deltaN_star)*log_sq+ (1/6)*at33(deltaN_star)*log_cub)
    return PS_t_val3

def loggPS_s3_AR(ka): 
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_s_val3  = P0_s3*np.exp((bs03_AR(deltaN_star) + bs13(deltaN_star)*log + 0.5*bs23(deltaN_star)*log_sq+(1/6)*bs33(deltaN_star)*log_cub))
    return loggPS_s_val3

def loggPS_t3_AR(ka):
    log = np.log(ka/k_star)
    log_sq = log**2
    log_cub = log**3
    loggPS_t_val3  = P0_t2*np.exp((bt03_AR(deltaN_star) + bt13(deltaN_star)*log + 0.5*bt23(deltaN_star)*log_sq+(1/6)*bt33(deltaN_star)*log_cub))
    return loggPS_t_val3

# %%
#III order scalar PPS 

plt.loglog(k_win, loggPS_s3(k_win), label = "III order scalar PPS (Auclair and Ringeval)")
plt.loglog(k_win, loggPS_s3_AR(k_win), label = "III order scalar PPS (Ballardini and Sirletti)")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{\cal R}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
# Error AR vs BS: 

error_AR_vs_BS_s = ( loggPS_s3(k_win)/ loggPS_s3_AR(k_win) - 1)*100

plt.plot(k_win, error_AR_vs_BS_s, label = " Error scalar AR vs SB")
plt.hlines(y = 0,xmin= 10**(-4), xmax=1e2 , color = 'k', ls="--",alpha=0.2)
plt.xscale('log')
plt.ylim([0.0008, +0.001])
plt.xlim([10**(-4), 1e2])
plt.ylabel(r'% Error ')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
#III order scalar PPS 

plt.loglog(k_win, loggPS_t3(k_win), label = "III order tensor PPS (Auclair and Ringeval)")
plt.loglog(k_win, loggPS_t3_AR(k_win), label = "III order tensor PPS (Ballardini and Sirletti)")
plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$P_{T}(k)$')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()

# %%
# Error AR vs BS: 

error_AR_vs_BS_t = ( loggPS_t3(k_win)/ loggPS_t3_AR(k_win) - 1)*100

plt.plot(k_win, error_AR_vs_BS_t, label = " Error tensor AR vs SB")
plt.hlines(y = 0,xmin= 10**(-4), xmax=1e2 , color = 'k', ls="--",alpha=0.2)
plt.xscale('log')
plt.ylim([0,0.0000001])
plt.xlim([10**(-4), 1e2])
plt.ylabel(r'% Error ')
plt.xlabel(r'$k\, \ [{\rm Mpc^{-1}}]$')
plt.legend()
